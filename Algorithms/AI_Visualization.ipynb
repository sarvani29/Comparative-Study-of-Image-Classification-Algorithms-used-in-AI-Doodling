# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
Algorithm = ['CNN-Adam Optimizer', 'K-Nearest Neighbors', 'CNN-SGD Optimizer', 'Multi-Layer Perceptron', 'Support Vector Machine - rbf', 'Support Vector Machine - Linear', 
         'Logistic Regression', 'Random Forest Classifier', 'Squeezenet/Vgg16']
Time = [7.5, 40.5, 8.3, 59.5, 89, 210, 2, 3.3, 64]
Accuracy = [93.4, 86.6, 85.8, 84.7, 82, 78.1, 75.6, 70.1, 22.5]
data = {'Algorithm': Algorithm, 'Time taken (in mins)': Time, 'Accuracy (in %)': Accuracy}
df = pd.DataFrame(data)
df[:9]
# Out:
#                          Algorithm  Time taken (in mins)  Accuracy (in %)
# 0               CNN-Adam Optimizer                   7.5             93.4
# 1              K-Nearest Neighbors                  40.5             86.6
# 2                CNN-SGD Optimizer                   8.3             85.8
# 3           Multi-Layer Perceptron                  59.5             84.7
# 4     Support Vector Machine - rbf                  89.0             82.0
# 5  Support Vector Machine - Linear                 210.0             78.1
# 6              Logistic Regression                   2.0             75.6
# 7         Random Forest Classifier                   3.3             70.1
# 8                 Squeezenet/Vgg16                  64.0             22.5

# %%
plt.title('Time taken')
sns.barplot(x='Algorithm', y='Time taken (in mins)', data=df, palette='summer')

# %%
plt.title('Accuracy')
sns.lineplot(x='Algorithm', y='Accuracy (in %)', data=df, sort=False)

# %%
#Create combo chart
fig, ax1 = plt.subplots(figsize=(10,6))
color = 'tab:green'
#bar plot creation
ax1.set_title('Results', fontsize=16)
ax1.set_xlabel('Algorithm', fontsize=16)
ax1.set_ylabel('Time taken (in mins)', fontsize=16)
ax1 = sns.barplot(x='Algorithm', y='Time taken (in mins)', data = df, palette='summer')
ax1.tick_params(axis='y')
#specify we want to share the same x-axis
ax2 = ax1.twinx()
color = 'tab:red'
#line plot creation
ax2.set_ylabel('Accuracy (%)', fontsize=16)
ax2 = sns.lineplot(x='Algorithm', y='Accuracy (in %)', data = df, sort=False, color=color)
ax2.tick_params(axis='y', color=color)
#show plot
plt.show()

# %%
fig, ax1 = plt.subplots(figsize=(10,6))
color = 'tab:green'
ax1.set_title('Results', fontsize=12)
ax1.set_xlabel('Algorithm', fontsize=12)
ax1.set_ylabel('Time taken (in mins)', fontsize=12, color=color)
ax2 = sns.barplot(x='Algorithm', y='Time taken (in mins)', data = df, palette='summer')
ax1.tick_params(axis='y')
ax2 = ax1.twinx()
color = 'tab:red'
ax2.set_ylabel('Accuracy (in %)', fontsize=12, color=color)
ax2 = sns.lineplot(x='Algorithm', y='Accuracy (in %)', data = df, sort=False, color=color)
ax2.tick_params(axis='y', color=color)
plt.show()
